# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv('True.csv')
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  ...                date
# 0  As U.S. budget fight looms, Republicans flip t...  ...  December 31, 2017
# 1  U.S. military to accept transgender recruits o...  ...  December 29, 2017
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...  December 31, 2017
# 3  FBI Russia probe helped by Australian diplomat...  ...  December 30, 2017
# 4  Trump wants Postal Service to charge 'much mor...  ...  December 29, 2017
#
# [5 rows x 4 columns]

# %%
fake.head()
# Out:
#                                                title  ...               date
# 0   Donald Trump Sends Out Embarrassing New Year’...  ...  December 31, 2017
# 1   Drunk Bragging Trump Staffer Started Russian ...  ...  December 31, 2017
# 2   Sheriff David Clarke Becomes An Internet Joke...  ...  December 30, 2017
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  ...  December 29, 2017
# 4   Pope Francis Just Called Out Donald Trump Dur...  ...  December 25, 2017
#
# [5 rows x 4 columns]

# %%
true['label'] = 1

# %%
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  ... label
# 0  As U.S. budget fight looms, Republicans flip t...  ...     1
# 1  U.S. military to accept transgender recruits o...  ...     1
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...  ...     1
# 3  FBI Russia probe helped by Australian diplomat...  ...     1
# 4  Trump wants Postal Service to charge 'much mor...  ...     1
#
# [5 rows x 5 columns]

# %%
fake.head()
# Out:
#                                                title  ... label
# 0   Donald Trump Sends Out Embarrassing New Year’...  ...     0
# 1   Drunk Bragging Trump Staffer Started Russian ...  ...     0
# 2   Sheriff David Clarke Becomes An Internet Joke...  ...     0
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  ...     0
# 4   Pope Francis Just Called Out Donald Trump Dur...  ...     0
#
# [5 rows x 5 columns]

# %%
news = pd.concat([fake,true],axis=0)

# %%
news.head()
# Out:
#                                                title  ... label
# 0   Donald Trump Sends Out Embarrassing New Year’...  ...     0
# 1   Drunk Bragging Trump Staffer Started Russian ...  ...     0
# 2   Sheriff David Clarke Becomes An Internet Joke...  ...     0
# 3   Trump Is So Obsessed He Even Has Obama’s Name...  ...     0
# 4   Pope Francis Just Called Out Donald Trump Dur...  ...     0
#
# [5 rows x 5 columns]

# %%
news.tail()
# Out:
#                                                    title  ... label
# 21412  'Fully committed' NATO backs new U.S. approach...  ...     1
# 21413  LexisNexis withdrew two products from Chinese ...  ...     1
# 21414  Minsk cultural hub becomes haven from authorities  ...     1
# 21415  Vatican upbeat on possibility of Pope Francis ...  ...     1
# 21416  Indonesia to buy $1.14 billion worth of Russia...  ...     1
#
# [5 rows x 5 columns]

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
news = news.sample(frac=1) #reshuffling

# %%
news.head()
# Out:
#                                                     text  label
# 7345   SAN DIEGO (Reuters) - The U.S. judge overseein...      1
# 5636   HAVANA (Reuters) - The governor of Colorado sa...      1
# 12313  MOSCOW (Reuters) - President Vladimir Putin wa...      1
# 15765  ISTANBUL (Reuters) - Amnesty International s T...      1
# 1681   WASHINGTON/NEW YORK (Reuters) - New York Gover...      1

# %%
news = news.reset_index(drop=True)

# %%
news.to_csv('news.csv', index=False)

# %%
news.head()
# Out:
#                                                 text  label
# 0  SAN DIEGO (Reuters) - The U.S. judge overseein...      1
# 1  HAVANA (Reuters) - The governor of Colorado sa...      1
# 2  MOSCOW (Reuters) - President Vladimir Putin wa...      1
# 3  ISTANBUL (Reuters) - Amnesty International s T...      1
# 4  WASHINGTON/NEW YORK (Reuters) - New York Gover...      1

# %%
import re

# %%
def wordopt(text):
    # Convert to lowercase
    text = text.lower()

    # Remove URLs (http, https, and www)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)

    # Remove HTML tags
    text = re.sub(r'<.*?>', '', text)

    # Remove all non-alphanumeric characters (except spaces)
    text = re.sub(r'[^\w\s]', '', text)

    # Remove digits
    text = re.sub(r'\d', '', text)

    # Remove newline characters
    text = re.sub(r'\n', '', text)

    return text  # Proper indentation for return

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        san diego reuters  the us judge overseeing a l...
# 1        havana reuters  the governor of colorado said ...
# 2        moscow reuters  president vladimir putin warne...
# 3        istanbul reuters  amnesty international s turk...
# 4        washingtonnew york reuters  new york governor ...
#                                ...
# 44893    london reuters  around half of britons believe...
# 44894    the new head of donald trump s presidential ca...
# 44895    the russians may not have hacked our elections...
# 44896    if texas lt governor dan patrick r thought he ...
# 44897    there are numerous crimes we report on every d...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        san diego reuters  the us judge overseeing a l...
# 1        havana reuters  the governor of colorado said ...
# 2        moscow reuters  president vladimir putin warne...
# 3        istanbul reuters  amnesty international s turk...
# 4        washingtonnew york reuters  new york governor ...
#                                ...
# 44893    london reuters  around half of britons believe...
# 44894    the new head of donald trump s presidential ca...
# 44895    the russians may not have hacked our elections...
# 44896    if texas lt governor dan patrick r thought he ...
# 44897    there are numerous crimes we report on every d...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 44893    1
# 44894    0
# 44895    0
# 44896    0
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
# Feature Extraction
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()

# %%
xv_train = vectorization.fit_transform(x_train)

# %%
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6464495 stored elements and shape (31428, 174786)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2715973 stored elements and shape (13470, 174786)>

# %%
# To create ML model - Logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9880475129918337

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6987
#            1       0.99      0.99      0.99      6483
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
# Decession Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test,y_test)
# Out:
# 0.9962880475129918

# %%
print(classification_report(y_test,pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      6987
#            1       1.00      1.00      1.00      6483
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
# Ensemble LEarning - Random Forest Classifier(to get rid of overfitting)

from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9888641425389755

# %%
print(classification_report(y_test,pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6987
#            1       0.99      0.99      0.99      6483
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
# Using Gradient Boost Classifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc =gbc.predict(xv_test)

# %%
gbc.score(xv_test,y_test)
# Out:
# 0.9962138084632517

# %%
print(classification_report(y_test,pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      6987
#            1       0.99      1.00      1.00      6483
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
# Model Output
def output_label(n):
    if n == 0:
        return "It is a Fake News"
    else:
        return "This news is True"

# %%
def manual_testing(news):
    testing_news = {"text" : [news]}
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    pred_lr = LR.predict(new_xv_test)
    pred_dtc = DTC.predict(new_xv_test)
    pred_gbc = gbc.predict(new_xv_test)
    pred_rfc = rfc.predict(new_xv_test)
    return "\n\nLR Prediction : {} \nGBC Prediction : {} \nRFC Prediction : {} \nDTC Prediction : {}".format(output_label(pred_lr[0]), output_label(pred_gbc[0]), output_label(pred_rfc[0]), output_label(pred_dtc[0]))

# %%
news_article = str(input())

# %%
manual_testing(news_article)
# Out:
# '\n\nLR Prediction : It is a Fake News \nGBC Prediction : It is a Fake News \nRFC Prediction : It is a Fake News \nDTC Prediction : It is a Fake News'
